# %%
import os 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Flatten
from matplotlib import ticker
from IPython.display import display

# %%
# детерминация случайных величин, отвечающих за выбор первоначальных весов и биасов
tf.compat.v1.set_random_seed(290)
tf.random.set_seed(290)

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print("X_train shape: ", x_train.shape)
print("Y_train shape: ", y_train.shape)

print("X_test shape: ", x_test.shape)
print("Y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (60000, 28, 28)
# Y_train shape:  (60000,)
# X_test shape:  (10000, 28, 28)
# Y_test shape:  (10000,)

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
y_train_cat = tf.keras.utils.to_categorical(y_train, 
                                            num_classes=10, 
                                            dtype='int32')

y_test_cat = tf.keras.utils.to_categorical(y_test, 
                                            num_classes=10, 
                                            dtype='int32')

# %%
fig, ax = plt.subplots(3,3)

fig.set_figwidth(9)
fig.set_figheight(9)

ax = ax.reshape(-1)

for i in range(len(ax)):   
    ax[i].imshow(x_train[i], cmap = plt.cm.binary)
    
plt.show()

# %%
model = keras.Sequential([
    Flatten(input_shape=(28,28,1)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# тренировка модели
history = model.fit(x_train, 
                    y_train_cat, 
                    batch_size = 32, 
                    epochs = 3, 
                    verbose = True, 
                    validation_split = 0.2, 
                    shuffle = True)
# Out:
# Epoch 1/3
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2864 - accuracy: 0.9189 - val_loss: 0.1508 - val_accuracy: 0.9574
# Epoch 2/3
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1267 - accuracy: 0.9626 - val_loss: 0.1182 - val_accuracy: 0.9652
# Epoch 3/3
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0864 - accuracy: 0.9746 - val_loss: 0.0910 - val_accuracy: 0.9721

# %%
# Вывод графика изменения ошибки

fig, ax = plt.subplots()
fig.set_figwidth(10)
fig.set_figheight(6)

plt.plot(history.history['loss'], label='loss',  linewidth=1.5, color='blue')
plt.plot(history.history['val_loss'], linestyle = '--', label='val_loss',  linewidth=3, color='red')

ax.set_title('График ошибки во время обучения', fontsize=20)
ax.set_ylabel('Ошибка', fontsize=15)
ax.set_xlabel('Эпохи', fontsize=15)

#  Устанавливаем интервал основных делений:
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.05))

#  Устанавливаем форматирование чисел основных делений:
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.d'))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

#  Устанавливаем форматирование делений:
ax.xaxis.set_tick_params(which = 'major', labelsize = 14)
ax.yaxis.set_tick_params(which = 'major', labelsize = 14)

ax.minorticks_on()
ax.grid(which='major', color = 'k', alpha = 0.6)
ax.grid(which='minor', color = 'gray', linestyle = ':')

ax.legend(fontsize = 15, facecolor = "white", loc = 'upper right')

plt.show()

# %%
# тест модели
model.evaluate(x_test, y_test_cat, batch_size = 32)
# Out:
# 313/313 [==============================] - 0s 708us/step - loss: 0.0874 - accuracy: 0.9732
# [0.0873827412724495, 0.9732000231742859]

# %%
# распознавание конкретных цифр
n = 154
x = np.expand_dims(x_test[n], axis=0)
res = model.predict(x)
print(res)
print(f"Распознанная цифра: {np.argmax(res)}")

plt.imshow(x_test[n], cmap=plt.cm.binary)
plt.show()
# Out:
# 1/1 [==============================] - 0s 75ms/step
# [[2.39456995e-07 9.91156936e-01 1.62202748e-04 2.46395497e-03
#   4.33810375e-04 1.43947345e-05 4.98932786e-05 4.91900044e-03
#   1.64221521e-04 6.35382661e-04]]
# Распознанная цифра: 1

# %%
# распознавание всей тестовой выборки
pred = model.predict(x_test)
pred = np.argmax(pred, axis=1)

print(pred.shape)

print(pred[:20])
print(y_test[:20])
# Out:
# 313/313 [==============================] - 0s 616us/step
# (10000,)
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]

# %%
# выделим неверные варианты
mask = pred == y_test
print(mask[:10])

x_false = x_test[~mask]
y_false = pred[~mask]

print(x_false.shape)
# Out:
# [ True  True  True  True  True  True  True  True  True  True]
# (268, 28, 28)

# %%
# выведем первые 5 неверных вариантов
for i in range(5):
    print(f"Значние сети: {y_false[i]}")
    plt.imshow(x_false[i], cmap=plt.cm.binary)
    plt.show()
# Out:
# Значние сети: 9
# Значние сети: 6
# Значние сети: 0
# Значние сети: 7
# Значние сети: 3
